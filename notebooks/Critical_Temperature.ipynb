# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
# %pip install lightgbm
# %pip install xgboost
# Out:
# Requirement already satisfied: numpy in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (2.5.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=2.3.3 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from seaborn) (2.5.2)
# Requirement already satisfied: pandas>=1.2 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.3)
# Requirement already satisfied: pillow>=9 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from scikit-learn) (2.5.2)
# Requirement already satisfied: scipy>=1.10.0 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from scikit-learn) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lightgbm in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (4.7.0)
# Requirement already satisfied: narwhals>=1.15 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from lightgbm) (2.25.0)
# Requirement already satisfied: numpy>=1.21.3 in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from lightgbm) (2.5.2)
# Requirement already satisfied: scipy in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from lightgbm) (1.18.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: xgboost in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (3.4.1)
# Requirement already satisfied: numpy in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from xgboost) (2.5.2)
# Requirement already satisfied: scipy in g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages (from xgboost) (1.18.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/mnt/user-data/uploads/1788537310081_train.csv")
print(f"Shape: {df.shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv("/mnt/user-data/uploads/1788537310081_train.csv")
#       2 print(f"Shape: {df.shape}")
#
# File g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File g:\Github Projects\Critical-Temperature-Prediction-For-Superconductors\.venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/user-data/uploads/1788537310081_train.csv'
